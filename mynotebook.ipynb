# %% [markdown]
# ## Introduction

# %%
import pandas as pd
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=["X","Y","Z"])

# %%
df.head()
# Out:
#    X  Y  Z
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.describe()
# Out:
#          X    Y    Z
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %% [markdown]
# ## Steam Games loc&iloc

# %%
import pandas as pd
sg = pd.read_csv('./found_datasets/steam_games_dataset.csv') #Steam Games dataset

# %%
sg.loc[1, "price"] = 6767

# %%
sg.loc[1:99,["name","positive","negative","price"]]
# Out:
#                                name  positive  negative  price
# 1                      Apex Legends    668053    326926   6767
# 2               PUBG: BATTLEGROUNDS   1520457   1037487      0
# 3                          Palworld    358266     22443   2999
# 4                   Team Fortress 2   1044264    117208      0
# 5   Call of Duty: Modern Warfare II    419594    294520   3849
# ..                              ...       ...       ...    ...
# 95                             DayZ    330349     99903   4999
# 96                     Satisfactory    225479      6585   2799
# 97                         NBA 2K20     30260     30413      0
# 98                   Risk of Rain 2    293127     20450   2499
# 99                EA SPORTS FIFA 23     86192     65227      0
#
# [99 rows x 4 columns]

# %%
sg.iloc[0:11, [1,5,6]]
# Out:
#                                 name  positive  negative
# 0   Counter-Strike: Global Offensive   7642084   1173003
# 1                       Apex Legends    668053    326926
# 2                PUBG: BATTLEGROUNDS   1520457   1037487
# 3                           Palworld    358266     22443
# 4                    Team Fortress 2   1044264    117208
# 5    Call of Duty: Modern Warfare II    419594    294520
# 6                New World: Aeternum    196798     90080
# 7                 Black Myth: Wukong   1111720     38378
# 8          Grand Theft Auto V Legacy   1739980    250576
# 9                      Left 4 Dead 2    940221     23762
# 10                          Unturned    506516     48852

# %%
sg.loc[sg['price'] > 1000, ['Name', 'Price']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 sg.loc[sg['price'] > 1000, ["Name","Price"]]
#
# File c:\Users\School\Documents\Code\complete-pandas-tutorial\.venv\Lib\site-packages\pandas\core\indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# File c:\Users\School\Documents\Code\complete-pandas-tutorial\.venv\Lib\site-packages\pandas\core\indexing.py:1386, in _LocIndexer._getitem_tuple(self, tup)
#    1384 with suppress(IndexingError):
#    1385     tup = self._expand_ellipsis(tup)
# -> 1386     return self._getitem_lowerdim(tup)
# ...
